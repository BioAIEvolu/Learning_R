# %%
# %load_ext rpy2.ipython

# %%
# %%R
# A <- matrix(1, 15, 15)
# A[4,7] <- 0
# persp(A, expand=0.5)

# %%
# %R curve(x^3+sin(x), from=0, to=10, n=1000, main=expression(x^3+sin(x)), ylab='f(x)')
# Out:
# R object with classes: ('list',) mapped to:
# <ListVector - Python:0x0000024F4642C508 / R:0x0000024F4BE768F8>
# [FloatVector, FloatVector]
#   x: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x0000024F4BBA8D48 / R:0x0000024F4BEA9540>
# [0.000000, 0.010010, 0.020020, 0.030030, ..., 9.969970, 9.979980, 9.989990, 10.000000]
#   y: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x0000024F4BC13508 / R:0x0000024F4BEAD430>
# [0.000000, 0.010011, 0.020027, 0.030053, ..., 990.499436, 993.478895, 996.464407, 999.455979]

# %%
from numpy import linspace, sin

# %%
x = linspace(0, 10 , 100)
y = sin(x) + 0.5*x

# %%
# %R -i x
# %R -i y

# %%
# %R plot(x,y)

# %%
mtcars = %R mtcars
# Out:
# D:\App\Python3\Anaconda\Anaconda\lib\site-packages\rpy2-2.9.4-py3.6-win-amd64.egg\rpy2\robjects\pandas2ri.py:191: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   res = PandasDataFrame.from_items(items)

# %%
mtcars
# Out:
#      mpg  cyl   disp     hp  drat     wt   qsec   vs   am  gear  carb
# 0   21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0   4.0   4.0
# 1   21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0   4.0   4.0
# 2   22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0  1.0   4.0   1.0
# 3   21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0   3.0   1.0
# 4   18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0   3.0   2.0
# 5   18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0  0.0   3.0   1.0
# 6   14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0  0.0   3.0   4.0
# 7   24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0  0.0   4.0   2.0
# 8   22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0  0.0   4.0   2.0
# 9   19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0  0.0   4.0   4.0
# 10  17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0  0.0   4.0   4.0
# 11  16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0  0.0   3.0   3.0
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
mdata = mtcars[['mpg', 'disp', 'hp']] 
sns.pairplot(mdata, diag_kind='kde', plot_kws={'alpha': 0.6})
